# %%
# Importaciones
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from geopy import distance

# %%
# Importando datos desde el archivo
nombrearchivo = "m30_2024_data_python.txt"
datafile = open(nombrearchivo ,"r")

# Cantidad de sensores
line = datafile.readline()
numSensores = int(line)
# IDs de los sensores
line = datafile.readline()
lista_Sensores = list(map(int, line.split()))
# Codigos de los sensores
line = datafile.readline()
lista_Codigos = list(map(str, line.split()))

# Cantidad de Fechas
line = datafile.readline()
numFechas = int(line)

print("num_sensores:", numSensores)
print("num_fechas:", numFechas)
line = datafile.readline()
ll = list(map(int, line.split()))
print(len(ll), numFechas)



# Grilla de datos
grillaIntensidad = np.zeros((numSensores, numFechas))
grillaOcupacion = np.zeros((numSensores, numFechas))
grillaCarga = np.zeros((numSensores, numFechas))
grillaVelocidad = np.zeros((numSensores, numFechas))

for i in range(numSensores):
    line = datafile.readline()
    ll = list(map(int, line.split()))
    if len(ll) != numFechas:
        print("Error!")
    grillaIntensidad[i] = ll
    line = datafile.readline()
    ll = list(map(int, line.split()))
    if len(ll) != numFechas:
        print("Error!")
    grillaOcupacion[i] = ll
    line = datafile.readline()
    ll = list(map(int, line.split()))
    if len(ll) != numFechas:
        print("Error!")
    grillaCarga[i] = ll
    line = datafile.readline()
    ll = list(map(int, line.split()))
    if len(ll) != numFechas:
        print("Error!")
    grillaVelocidad[i] = ll
# Out:
# num_sensores: 240
# num_fechas: 35136
# 2024-12-31 23:45:00
# 35136 35136
# Importando sensor 6640
# Importando sensor 6641
# Importando sensor 6642
# Importando sensor 6643
# Importando sensor 6644
# Importando sensor 6645
# Importando sensor 6647
# Importando sensor 6648
# Importando sensor 6649
# Importando sensor 6650
# Importando sensor 6651
# Importando sensor 6652
# Importando sensor 6653
# Importando sensor 6654
# Importando sensor 6655
# Importando sensor 10175
# Importando sensor 10265
# Importando sensor 3817
# Importando sensor 3819
# Importando sensor 10172
# Importando sensor 10266
# Importando sensor 3799
# Importando sensor 3800
# Importando sensor 6666
# Importando sensor 3488
# Importando sensor 3489
# Importando sensor 10662
# Importando sensor 3611
# Importando sensor 6669
# Importando sensor 6668
# Importando sensor 3490
# Importando sensor 3491
# Importando sensor 3492
# Importando sensor 3493
# Importando sensor 3816
# Importando sensor 6670
# Importando sensor 6671
# Importando sensor 6672
# Importando sensor 6673
# Importando sensor 6674
# Importando sensor 7124
# Importando sensor 6677
# Importando sensor 6678
# Importando sensor 6679
# Importando sensor 6680
# Importando sensor 6681
# Importando sensor 6682
# Importando sensor 6683
# Importando sensor 6684
# Importando sensor 6685
# Importando sensor 6686
# Importando sensor 6687
# Importando sensor 6688
# Importando sensor 6689
# Importando sensor 10660
# Importando sensor 6691
# Importando sensor 7125
# Importando sensor 6693
# Importando sensor 6694
# Importando sensor 6813
# Importando sensor 6695
# Importando sensor 10659
# Importando sensor 10180
# Importando sensor 6698
# Importando sensor 6815
# Importando sensor 6817
# Importando sensor 6699
# Importando sensor 6700
# Importando sensor 3801
# Importando sensor 6706
# Importando sensor 6707
# Importando sensor 7130
# Importando sensor 7013
# Importando sensor 7014
# Importando sensor 6713
# Importando sensor 3821
# Importando sensor 3822
# Importando sensor 3823
# Importando sensor 6714
# Importando sensor 6715
# Importando sensor 6716
# Importando sensor 6717
# Importando sensor 6719
# Importando sensor 6720
# Importando sensor 6722
# Importando sensor 6723
# Importando sensor 6725
# Importando sensor 6726
# Importando sensor 6729
# Importando sensor 6730
# Importando sensor 6731
# Importando sensor 6732
# Importando sensor 10661
# Importando sensor 6734
# Importando sensor 6735
# Importando sensor 6736
# Importando sensor 10194
# Importando sensor 6737
# Importando sensor 6738
# Importando sensor 6739
# Importando sensor 6740
# Importando sensor 6742
# Importando sensor 6741
# Importando sensor 10267
# Importando sensor 6743
# Importando sensor 6744
# Importando sensor 6745
# Importando sensor 6746
# Importando sensor 7126
# Importando sensor 6748
# Importando sensor 10177
# Importando sensor 6749
# Importando sensor 6750
# Importando sensor 10179
# Importando sensor 10178
# Importando sensor 6753
# Importando sensor 6754
# Importando sensor 6755
# Importando sensor 6757
# Importando sensor 6758
# Importando sensor 6759
# Importando sensor 6760
# Importando sensor 6761
# Importando sensor 6763
# Importando sensor 6764
# Importando sensor 6765
# Importando sensor 3531
# Importando sensor 3532
# Importando sensor 3533
# Importando sensor 6948
# Importando sensor 6766
# Importando sensor 6768
# Importando sensor 3836
# Importando sensor 3558
# Importando sensor 3559
# Importando sensor 6769
# Importando sensor 6697
# Importando sensor 3597
# Importando sensor 6816
# Importando sensor 6770
# Importando sensor 3598
# Importando sensor 3599
# Importando sensor 3560
# Importando sensor 6771
# Importando sensor 3494
# Importando sensor 6772
# Importando sensor 6774
# Importando sensor 6775
# Importando sensor 6934
# Importando sensor 6935
# Importando sensor 3521
# Importando sensor 6712
# Importando sensor 3837
# Importando sensor 3539
# Importando sensor 3536
# Importando sensor 6819
# Importando sensor 3495
# Importando sensor 3561
# Importando sensor 6667
# Importando sensor 3600
# Importando sensor 3838
# Importando sensor 3839
# Importando sensor 6777
# Importando sensor 7127
# Importando sensor 6778
# Importando sensor 6779
# Importando sensor 6822
# Importando sensor 6780
# Importando sensor 6938
# Importando sensor 6939
# Importando sensor 6942
# Importando sensor 6941
# Importando sensor 6949
# Importando sensor 6950
# Importando sensor 6781
# Importando sensor 6782
# Importando sensor 3496
# Importando sensor 6783
# Importando sensor 6784
# Importando sensor 6785
# Importando sensor 6932
# Importando sensor 7128
# Importando sensor 3797
# Importando sensor 10198
# Importando sensor 10200
# Importando sensor 10201
# Importando sensor 10199
# Importando sensor 3538
# Importando sensor 6789
# Importando sensor 10176
# Importando sensor 6661
# Importando sensor 6790
# Importando sensor 7131
# Importando sensor 3827
# Importando sensor 3828
# Importando sensor 3826
# Importando sensor 6791
# Importando sensor 6792
# Importando sensor 10204
# Importando sensor 10203
# Importando sensor 10268
# Importando sensor 6762
# Importando sensor 10205
# Importando sensor 10207
# Importando sensor 3761
# Importando sensor 3762
# Importando sensor 3763
# Importando sensor 3703
# Importando sensor 3704
# Importando sensor 3705
# Importando sensor 6793
# Importando sensor 6823
# Importando sensor 10211
# Importando sensor 6794
# Importando sensor 6936
# Importando sensor 6937
# Importando sensor 6795
# Importando sensor 7012
# Importando sensor 10208
# Importando sensor 6943
# Importando sensor 6944
# Importando sensor 6952
# Importando sensor 6951
# Importando sensor 6796
# Importando sensor 6797
# Importando sensor 6798
# Importando sensor 6799
# Importando sensor 6800
# Importando sensor 6801
# Importando sensor 6802
# Importando sensor 6804
# Importando sensor 3706
# Importando sensor 6805
# Importando sensor 6806
# Importando sensor 10210
# Importando sensor 6807
# Importando sensor 6808
# Importando sensor 6933
# Importando sensor 7129
# Importando sensor 7015
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 50
#      48 grillaOcupacion[i] = ll
#      49 line = datafile.readline()
# ---> 50 ll = list(map(int, line.split()))
#      51 if len(ll) != numFechas:
#      52     print("Error!")
#
# ValueError: invalid literal for int() with base 10: '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0
