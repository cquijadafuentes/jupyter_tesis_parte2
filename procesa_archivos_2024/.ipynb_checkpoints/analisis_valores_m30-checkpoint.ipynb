# %%
import matplotlib.pyplot as plt

# %%
hE = []
sumaE = 0
cantE = 0
with open('m30_2024_datos_histograma_atrib2_dataEstructura.txt') as fp:
    for line in fp:
        data = line.split()
        x = int(data[1])
        hE.append(x)
        sumaE += x
        cantE += 1
prom = sumaE / cantE

# %%
for i in range(5):
    print(h[i])
# Out:
# 2982762
# 1426498
# 1469131
# 506946
# 567245

# %%
plt.plot(hE)
plt.title("Histograma de datos [Estructura]")
plt.savefig('m30_2024_datos_histograma_atrib2_dataEstructura.png', bbox_inches='tight')
plt.grid(axis='y')
#plt.yscale('log')
plt.legend()
plt.show()
plt.close()
# Out:
# /tmp/ipykernel_18895/29734201.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
hO = []
with open('m30_2024_datos_histograma_atrib2_dataOriginal.txt') as fp:
    for line in fp:
        data = line.split()
        hO.append(int(data[1]))

# %%
plt.plot(hO)
plt.title("Histograma de datos [Original]")
plt.savefig('m30_2024_datos_histograma_atrib2_dataOriginal.png', bbox_inches='tight')
plt.grid(axis='y')
#plt.yscale('log')
plt.legend()
plt.show()
plt.close()
# Out:
# /tmp/ipykernel_18895/1704090584.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
