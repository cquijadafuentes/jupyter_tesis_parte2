# %%
import zlib
import numpy as np

# %%
def leer_archivo(nombre_archivo):
    """Lee el archivo y devuelve los datos estructurados"""
    with open(nombre_archivo, 'r') as f:
        lineas = f.readlines()
    
    n, m = map(int, lineas[0].split())
    ids = lineas[1].strip().split()
    datos = np.array([list(map(int, linea.strip().split())) for linea in lineas[2:2+n]])
    
    return n, m, ids, datos

# %%
def codificar_alt1_sin_cuantizacion(datos):
    """Alternativa 1 pura sin cuantización"""
    encoded = np.zeros_like(datos)
    encoded[:, 0] = datos[:, 0]
    for i in range(1, datos.shape[1]):
        encoded[:, i] = datos[:, i] - datos[:, i-1]
    return encoded

# %%
def codificar_hibrido_sin_cuantizacion(datos):
    """Híbrido sin cuantización, usando floats nativos"""
    corr_matrix = np.corrcoef(datos)
    ref_index = np.argmax(np.mean(corr_matrix, axis=1))
    referencia = datos[ref_index]
    
    # Diferencias espaciales y temporales
    dif_espacial = datos - referencia
    dif_espacial[ref_index] = referencia
    deltas = np.diff(dif_espacial, axis=1, prepend=0)
    return deltas

# %%
def codificar_code2_corrdatos(datos):
    code1 = np.zeros_like(datos)
    code1[:, 0] = datos[:, 0]
    for i in range(1, datos.shape[1]):
        code1[:, i] = datos[:, i] - datos[:, i-1]
    """ Se usa como valor de correlación los datos originales """
    corr_matrix = np.corrcoef(datos)
    ref_index = np.argmax(np.mean(corr_matrix, axis=1))
    print("Indice de referencia:", ref_index)
    referencia = code1[ref_index]
    
    # Diferencias espaciales y temporales
    dif_espacial = code1 - referencia
    dif_espacial[ref_index] = referencia
    deltas = np.diff(dif_espacial, axis=1, prepend=0)
    return deltas

# %%
def codificar_code2_corrcode1(datos):
    code1 = np.zeros_like(datos)
    code1[:, 0] = datos[:, 0]
    for i in range(1, datos.shape[1]):
        code1[:, i] = datos[:, i] - datos[:, i-1]
    """ Se usa como valor de correlación los datos originales """
    corr_matrix = np.corrcoef(code1)
    ref_index = np.argmax(np.mean(corr_matrix, axis=1))
    print("Indice de referencia:", ref_index)
    referencia = code1[ref_index]
    
    # Diferencias espaciales y temporales
    dif_espacial = code1 - referencia
    dif_espacial[ref_index] = referencia
    deltas = np.diff(dif_espacial, axis=1, prepend=0)
    return deltas

# %%
def comprimir_justo(datos_codificados):
    """Compresión usando representación binaria nativa de floats (64 bits)"""
    return zlib.compress(datos_codificados.tobytes())

# %%
def comprime_con_archivo_de_grupos(filenameGroups):
    with open(filenameGroups, 'r') as f:
        lineas = f.readlines()
    gs = list(map(int, lineas[0].split()))
    p = 1
    for g in gs:
        idsG = lineas[p].split()
        dataG = np.zeros((g, m))
        posG = 0
        for idG in idsG:
            indice = ids.index(idG)
            dataG[posG] = datos[indice]
            posG += 1
        print("Analizando grupo", p)
        print(g, "IDs:", idsG)
        print("Datos:", dataG)
        
        # Codificar
        alt1 = codificar_alt1_sin_cuantizacion(dataG)
        hibrido = codificar_hibrido_sin_cuantizacion(dataG)
        code2fd = codificar_code2_corrdatos(dataG)
        code2fc = codificar_code2_corrcode1(dataG)
        
        # Comprimir
        c_alt1 = len(comprimir_justo(alt1))
        c_hibrido = len(comprimir_justo(hibrido))
        c_code2fd = len(comprimir_justo(code2fd))
        c_code2fc = len(comprimir_justo(code2fc))
        
        # Resultados
        print("\n================== COMPARACIÓN JUSTA (sin cuantización) ==================")
        print(f"Alternativa 1: {c_alt1} bytes")
        print(f"Híbrido: {c_hibrido} bytes ({((c_alt1 - c_hibrido)/c_alt1)*100:.1f}% mejor)")
        print(f"Code 2 (Corr. Datos): {c_code2fd} bytes ({((c_alt1 - c_code2fd)/c_alt1)*100:.1f}% mejor)")
        print(f"Code 2 (Corr. Code 1): {c_code2fc} bytes ({((c_alt1 - c_code2fc)/c_alt1)*100:.1f}% mejor)")
        
        p += 1
        print("==============================================================================")

# %%
file_groups_normal = "../procesa_archivos_2024/outputdata_m30_fulldates/archivos_articulo/m30_2024_ids_estructura_intensidad.txt"
print("Comprimiendo con el archivo de grupos:", file_groups_normal)
comprime_con_archivo_de_grupos(file_groups_normal)
# Out:
# Comprimiendo con el archivo de grupos: ../procesa_archivos_2024/outputdata_m30_fulldates/archivos_articulo/m30_2024_ids_estructura_intensidad.txt
# Analizando grupo 1
# 28 IDs: ['6641', '6642', '6644', '6648', '6650', '6654', '10175', '3799', '6666', '3491', '3816', '6672', '6679', '6680', '6683', '6685', '6687', '6689', '6691', '6693', '6694', '6695', '6698', '6699', '6700', '3801', '6706', '7013']
# Datos: [[ 190.  156.  912. ...  525.  460.  248.]
#  [ 196.  205. 1140. ...  740.  588.  356.]
#  [ 136.  124.  776. ...  572.  424.  260.]
#  ...
#  [  72.   76.  368. ...  152.  205.  148.]
#  [  56.   56.  319. ...  140.  152.   80.]
#  [  80.  132.  116. ...  108.  108.   73.]]
# Indice de referencia: 2
# Indice de referencia: 8
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 1953166 bytes
# Híbrido: 2032326 bytes (-4.1% mejor)
# Code 2 (Corr. Datos): 2115550 bytes (-8.3% mejor)
# Code 2 (Corr. Code 1): 2141550 bytes (-9.6% mejor)
# ==============================================================================
# Analizando grupo 2
# 23 IDs: ['6643', '6645', '6647', '6649', '6651', '6655', '10265', '3819', '3800', '3488', '3490', '3492', '6670', '6673', '6677', '6681', '7125', '6813', '10180', '6815', '6817', '7130', '7014']
# Datos: [[ 21.  32.  97. ...  28.  24.  20.]
#  [ 84.  76. 376. ... 224. 236. 132.]
#  [116. 128. 724. ... 320. 316. 248.]
#  ...
#  [ 20.  13.  96. ...  40.  68.  64.]
#  [100.  88. 348. ... 229. 164. 124.]
#  [ 32.  16.  96. ...  40.  40.  28.]]
# Indice de referencia: 1
# Indice de referencia: 9
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 1553519 bytes
# Híbrido: 1624420 bytes (-4.6% mejor)
# Code 2 (Corr. Datos): 1689936 bytes (-8.8% mejor)
# Code 2 (Corr. Code 1): 1712785 bytes (-10.3% mejor)
# ==============================================================================
# Analizando grupo 3
# 35 IDs: ['6713', '3823', '6715', '6717', '6720', '6722', '6725', '6729', '6732', '6734', '6737', '6743', '6746', '6749', '6753', '6758', '6763', '6765', '3532', '3533', '6766', '6768', '3836', '3558', '6769', '3597', '6770', '3598', '3599', '3560', '6771', '3494', '6772', '6775', '6934']
# Datos: [[ 117.  109.  637. ...  313.  269.  229.]
#  [ 268.  245. 1168. ...  501.  408.  347.]
#  [ 264.  240. 1140. ...  528.  448.  388.]
#  ...
#  [ 116.  128.  461. ...  149.  251.  188.]
#  [ 192.  151.  601. ...  272.  461.  269.]
#  [ 140.   64.  296. ...  116.  164.  172.]]
# Indice de referencia: 33
# Indice de referencia: 6
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 2450823 bytes
# Híbrido: 2575760 bytes (-5.1% mejor)
# Code 2 (Corr. Datos): 2680782 bytes (-9.4% mejor)
# Code 2 (Corr. Code 1): 2671312 bytes (-9.0% mejor)
# ==============================================================================
# Analizando grupo 4
# 18 IDs: ['6714', '6716', '6723', '6726', '6730', '6735', '6738', '6739', '6744', '6750', '10179', '6754', '6761', '6948', '3559', '6697', '6816', '6935']
# Datos: [[ 60.  60. 376. ... 100. 127.  85.]
#  [ 25.  29. 148. ...  32.  48.  28.]
#  [216. 144. 957. ... 457. 308. 313.]
#  ...
#  [ 76.  93. 364. ... 176. 164. 137.]
#  [ 24.  49. 328. ... 120.  68.  71.]
#  [ 20.  20. 189. ...  65.  60.  24.]]
# Indice de referencia: 3
# Indice de referencia: 3
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 1216130 bytes
# Híbrido: 1297734 bytes (-6.7% mejor)
# Code 2 (Corr. Datos): 1345180 bytes (-10.6% mejor)
# Code 2 (Corr. Code 1): 1345180 bytes (-10.6% mejor)
# ==============================================================================
# Analizando grupo 5
# 136 IDs: ['6640', '6652', '6653', '3817', '10172', '10266', '3489', '10662', '3611', '6669', '6668', '3493', '6671', '6674', '7124', '6678', '6682', '6684', '6686', '6688', '10660', '10659', '6707', '3821', '3822', '6719', '6731', '10661', '6736', '10194', '6740', '6742', '6741', '10267', '6745', '7126', '6748', '10177', '10178', '6755', '6757', '6759', '6760', '6764', '3531', '6774', '3521', '6712', '3837', '3539', '3536', '6819', '3495', '3561', '6667', '3600', '3838', '3839', '6777', '7127', '6778', '6779', '6822', '6780', '6938', '6939', '6942', '6941', '6949', '6950', '6781', '6782', '3496', '6783', '6784', '6785', '6932', '7128', '3797', '10198', '10200', '10201', '10199', '3538', '6789', '10176', '6661', '6790', '7131', '3827', '3828', '3826', '6791', '6792', '10204', '10203', '10268', '6762', '10205', '10207', '3761', '3762', '3763', '3703', '3704', '3705', '6793', '6823', '10211', '6794', '6936', '6937', '6795', '7012', '10208', '6943', '6944', '6952', '6951', '6796', '6797', '6798', '6799', '6800', '6801', '6802', '6804', '3706', '6805', '6806', '10210', '6807', '6808', '6933', '7129', '7015']
# Datos: [[ 64. 113. 568. ... 348. 228. 196.]
#  [ 16.  40. 132. ...  84.  40.  65.]
#  [ 24.  28.  88. ...  48.  35.  20.]
#  ...
#  [128. 161. 600. ... 268. 316. 212.]
#  [ 32.  36. 252. ... 119. 104.  48.]
#  [ 36.  24. 156. ...  32.  64.  48.]]
# Indice de referencia: 24
# Indice de referencia: 46
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 8770015 bytes
# Híbrido: 9636294 bytes (-9.9% mejor)
# Code 2 (Corr. Datos): 9996972 bytes (-14.0% mejor)
# Code 2 (Corr. Code 1): 10224149 bytes (-16.6% mejor)
# ==============================================================================

# %%
file_groups_similitud = "../procesa_archivos_2024/outputdata_m30_fulldates/archivos_articulo/m30_2024_ids_por_grupo_intensidad.txt"
print("Comprimiendo con el archivo de grupos:", file_groups_similitud)
comprime_con_archivo_de_grupos(file_groups_similitud)
# Out:
# Comprimiendo con el archivo de grupos: ../procesa_archivos_2024/outputdata_m30_fulldates/archivos_articulo/m30_2024_ids_por_grupo_intensidad.txt
# Analizando grupo 1
# 48 IDs: ['3819', '6666', '3799', '3490', '6642', '6685', '6725', '6654', '6715', '6641', '3491', '6650', '10265', '6683', '3532', '6782', '6775', '6779', '6758', '3823', '6789', '3521', '6679', '3837', '6738', '6726', '6689', '10175', '6644', '6723', '6737', '6649', '6746', '3488', '6743', '6648', '6655', '6734', '6729', '3816', '6680', '6749', '6672', '6651', '6647', '6753', '6720', '3492']
# Datos: [[ 459.  360. 1696. ... 1088.  903.  760.]
#  [ 288.  297. 1272. ...  892.  792.  589.]
#  [ 277.  260. 1277. ...  833.  752.  584.]
#  ...
#  [ 236.  225.  864. ...  408.  600.  340.]
#  [ 176.  164.  720. ...  332.  379.  252.]
#  [ 320.  312. 1104. ...  640.  261.  304.]]
# Indice de referencia: 2
# Indice de referencia: 1
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 3434321 bytes
# Híbrido: 3543480 bytes (-3.2% mejor)
# Code 2 (Corr. Datos): 3683904 bytes (-7.3% mejor)
# Code 2 (Corr. Code 1): 3701969 bytes (-7.8% mejor)
# ==============================================================================
# Analizando grupo 2
# 48 IDs: ['6717', '6732', '6713', '6793', '6780', '6735', '10207', '6739', '6691', '6778', '10198', '6695', '6693', '3800', '6686', '6938', '6770', '6794', '6682', '6765', '3597', '6766', '3836', '6949', '6937', '6822', '3822', '6750', '3536', '6670', '3705', '6798', '6769', '3558', '6942', '6687', '10180', '10208', '6722', '10204', '6932', '10179', '10203', '6823', '6697', '6772', '6933', '6744']
# Datos: [[187. 164. 724. ... 368. 392. 272.]
#  [196. 149. 856. ... 136. 220. 108.]
#  [117. 109. 637. ... 313. 269. 229.]
#  ...
#  [116. 128. 461. ... 149. 251. 188.]
#  [128. 161. 600. ... 268. 316. 212.]
#  [280. 216. 843. ... 184. 208. 348.]]
# Indice de referencia: 26
# Indice de referencia: 17
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 3340085 bytes
# Híbrido: 3435003 bytes (-2.8% mejor)
# Code 2 (Corr. Datos): 3573830 bytes (-7.0% mejor)
# Code 2 (Corr. Code 1): 3579117 bytes (-7.2% mejor)
# ==============================================================================
# Analizando grupo 3
# 48 IDs: ['6684', '6807', '3493', '3533', '6763', '6667', '6645', '3801', '7130', '6952', '6943', '6755', '10177', '3560', '10210', '3599', '10268', '3531', '6640', '6768', '3839', '7127', '3704', '6783', '6771', '6700', '6805', '6688', '6714', '6804', '6694', '6699', '6674', '3828', '6801', '3495', '6730', '6719', '6761', '6934', '3598', '6813', '3494', '10172', '6791', '6748', '3611', '10205']
# Datos: [[109.  84. 511. ... 352. 405. 261.]
#  [127. 116. 540. ... 297. 252. 240.]
#  [159. 100. 493. ... 273. 271. 204.]
#  ...
#  [120. 124. 376. ... 312. 212. 216.]
#  [136. 144. 564. ... 341. 197. 220.]
#  [ 56.  68. 239. ... 144. 168. 204.]]
# Indice de referencia: 8
# Indice de referencia: 7
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 3243058 bytes
# Híbrido: 3371142 bytes (-3.9% mejor)
# Code 2 (Corr. Datos): 3514358 bytes (-8.4% mejor)
# Code 2 (Corr. Code 1): 3500631 bytes (-7.9% mejor)
# ==============================================================================
# Analizando grupo 4
# 48 IDs: ['6731', '3763', '6736', '6677', '6706', '10211', '3761', '10266', '6816', '6781', '6790', '6698', '3538', '6802', '6745', '6785', '3539', '6815', '3600', '10194', '6800', '3817', '6797', '6760', '6754', '6796', '3706', '6759', '6757', '6741', '3797', '3559', '6671', '6740', '10661', '6669', '6935', '10199', '6643', '3826', '6936', '3821', '6668', '3489', '7015', '6673', '3838', '6681']
# Datos: [[ 88.  84. 428. ... 128. 120.  92.]
#  [117. 151. 552. ... 243. 201. 173.]
#  [ 65.  56. 220. ... 117. 149. 152.]
#  ...
#  [108.  70. 216. ... 156. 151. 100.]
#  [ 72.  60. 236. ... 153. 145.  63.]
#  [101.  92. 272. ... 180. 167.  95.]]
# Indice de referencia: 0
# Indice de referencia: 11
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 3094462 bytes
# Híbrido: 3290831 bytes (-6.3% mejor)
# Code 2 (Corr. Datos): 3438298 bytes (-11.1% mejor)
# Code 2 (Corr. Code 1): 3419235 bytes (-10.5% mejor)
# ==============================================================================
# Analizando grupo 5
# 48 IDs: ['7129', '10178', '10267', '10662', '10176', '6661', '6777', '6806', '6799', '7014', '6950', '6742', '7131', '6817', '6819', '6951', '6652', '10200', '6716', '6948', '6678', '3703', '6784', '3762', '10201', '7126', '3561', '6939', '6944', '3496', '7125', '7128', '6764', '7012', '6762', '6653', '10660', '6792', '7013', '6712', '10659', '6774', '6707', '6941', '6808', '7124', '3827', '6795']
# Datos: [[ 32.  36. 252. ... 119. 104.  48.]
#  [112.  83. 288. ... 154. 180. 160.]
#  [ 60.  64. 293. ... 192. 192. 132.]
#  ...
#  [ 12.  36.  80. ...   0.   0.   0.]
#  [ 32.   7.  28. ...  68.  44.  44.]
#  [  5.  36.  44. ...  24.  12.  20.]]
# Indice de referencia: 0
# Indice de referencia: 13
#
# ================== COMPARACIÓN JUSTA (sin cuantización) ==================
# Alternativa 1: 2821896 bytes
# Híbrido: 3148534 bytes (-11.6% mejor)
# Code 2 (Corr. Datos): 3314327 bytes (-17.5% mejor)
# Code 2 (Corr. Code 1): 3275995 bytes (-16.1% mejor)
# ==============================================================================

# %%
"""
Fuentes posibles de información sobre autocorrelación temporal

https://numpy.org/doc/2.2/reference/generated/numpy.corrcoef.html
https://en.wikipedia.org/wiki/Pearson_correlation_coefficient
https://online.stat.psu.edu/stat462/node/188/

https://students.aiu.edu/submissions/profiles/resources/onlineBook/z2v3K5_Statistics_for_Engineers_and_Scientists_3rd.pdf
https://spada.uns.ac.id/pluginfile.php/221008/mod_resource/content/1/ProbabilityStatistics_for_EngineersScientists(9th_Edition)_Walpole.pdf
https://en.wikipedia.org/wiki/Autocorrelation
https://www3.cs.stonybrook.edu/~skiena/691/lectures/lecture14.pdf

"""
